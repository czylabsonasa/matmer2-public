% %% [markdown]
% ### F1
%
% Vezesse le a
% $$
% y'+y=2e^{3t}-1
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,3]×[−2,2]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F2
%
% Vezesse le a
% $$
% y'+y=3e^{2t}+1
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,3]×[−2,2]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F3
%
% Vezesse le a
% $$
% y'-2y=2e^{4t}-1
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,-2]×[−10,10]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F4
%
% Vezesse le a
% $$
% y'-3y=-e^{2t}-1
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,-2]×[−20,10]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F5
%
% Vezesse le a
% $$
% y'+y=e^{2t}-3
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,0]×[−3,2]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F6
%
% Vezesse le a
% $$
% y'-2y=-2e^{2t}+2
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,-2]×[−2,10]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F7
%
% Vezesse le a
% $$
% y'-2y=-e^{2t}+2
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,3]×[−3,10]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F8
%
% Vezesse le a
% $$
% y'-y = 2e^{3t}+4
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [−3,-2]×[−2,10]-en és rajzoltassa rá az
% y(−3)=-1,  y(−3)=0,  y(−3)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F9
%
% Vezesse le a
% $$
% y'-3y=-3e^{3t}+3
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[-3,10]-en és rajzoltassa rá az y(-4)=-1,  y(-4)=0,  y(-4)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F10
%
% Vezesse le a
% $$
% y'-3y = -2e^{3t}+3
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[-3,10]-en és rajzoltassa rá az
% y(-4)=-1,  y(-4)=0,  y(-4)=1 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F11
%
% Vezesse le a
% $$
% y'-2y = 2e^{3t}-6
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[−3,10]-en és rajzoltassa rá az
% y(-4)=2,  y(-4)=4,  y(-4)=6 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F12
%
% Vezesse le a
% $$
% y'-2y = -2e^{t}-1
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[−3,10]-en és rajzoltassa rá az
% y(-4)=0,  y(-4)=1,  y(-4)=2 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F13
%
% Vezesse le a
% $$
% y'-2y = -e^{3t}-5
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[−3,10]-en és rajzoltassa rá az
% y(-4)=1,  y(-4)=3,  y(-4)=5 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F14
%
% Vezesse le a
% $$
% y'-y = -2e^{3t}-4
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[−3,10]-en és rajzoltassa rá az
% y(-4)=1,  y(-4)=3,  y(-4)=5 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F15
%
% Vezesse le a
% $$
% y'-2y = 2e^{3t}-6
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-4,-3]×[−3,10]-en és rajzoltassa rá az
% y(-4)=1,  y(-4)=3,  y(-4)=5 kezdeti értékekhez tartozó megoldásokat is.

% %% [markdown]
% ### F16
%
% Vezesse le a
% $$
% y'-5y=-3e^{4t}-2
% $$
% kde megoldását kézzel. Oldja meg a Matlab/Octave dsolve függvénye segítségével is. Ábrázolja az egyenlet vektormezejét a [-5,-4]×[−3,10]-en és rajzoltassa rá az
% y(-5)=-1,  y(-5)=0,  y(-5)=1 kezdeti értékekhez tartozó megoldásokat is.
