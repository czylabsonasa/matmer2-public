% %% [markdown]
% # Negyedik projekt
%
%
% ## Általános leírás
% * Oldja meg (közelítő) `hatványsor` módszerrel a kezdeti érték feladatot.
% * A folyamat értékét a kérdéses pontban számolja ki $5.,10.,20.,30.$ rendű közelítésekkel és hasonlítsa össze a kapottakat az ```ode45``` által számolttal!
%
%
% # A feladatok
%
% ## F1
% \begin{gather*}
%    y'' - 2y' - y = 1+t\\
%     y(0)=2\\
%     y'(0)=-\frac{2}{10}\\
% y(2.9)=?
% \end{gather*}
%
% ---
%
% ## F2
% \begin{gather*}
%    y'' - y' + y = t\\
%     y(0)=1\\
%     y'(0)=-\frac{3}{10}\\
% y(4)=?
% \end{gather*}
%
% ---
%
% ## F3
% \begin{gather*}
%    y'' + y' - y = t^2\\
%     y(0)=0\\
%     y'(0)=-1\\
% y(2.5)=?
% \end{gather*}
%
% ---
%
% ## F4
% \begin{gather*}
%    y'' + 2y' - y = 2\\
%     y(0)=1\\
%     y'(0)=1\\
% y(3)=?
% \end{gather*}
%
% ---
%
% ## F5
% \begin{gather*}
%    y'' +2y' + y = -t\\
%     y(0)=2\\
%     y'(0)=-\frac{2}{10}\\
% y(3.5)=?
% \end{gather*}
%
% ---
%
% ## F6
% \begin{gather*}
%    y'' - 2y' - y = 1+t\\
%     y(0)=2\\
%     y'(0)=-\frac{2}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
%
%
% ## F7
% \begin{gather*}
%    y'' + 3y' - y = 1+t\\
%     y(0)=1\\
%     y'(0)=-\frac{6}{10}\\
% y(3.5)=?
% \end{gather*}
%
% ---
%
% ## F8
% \begin{gather*}
%    y'' - y' - 2y = 2+t^2\\
%     y(0)=0.5\\
%     y'(0)=0.5\\
% y(4)=?
% \end{gather*}
%
% ---
%
% ## F9
% \begin{gather*}
%    2y'' + 2y' - y = 0.5*t\\
%     y(0)=0\\
%     y'(0)=-1\\
% y(2.5)=?
% \end{gather*}
%
% ---
%
% ## F10
% \begin{gather*}
%    3y'' + 2y' - 3y = 2\\
%     y(0)=-1\\
%     y'(0)=1\\
% y(3)=?
% \end{gather*}
%
% ---
%
% ## F11
% \begin{gather*}
%    0.5y'' +2y' + y = -t^2\\
%     y(0)=0\\
%     y'(0)=1\\
% y(3.2)=?
% \end{gather*}
%
% ---
%
% ## F12
% \begin{gather*}
%    y'' - 2y' - y = 1+t\\
%     y(0)=2\\
%     y'(0)=-\frac{2}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
%
%
% ## F13
% \begin{gather*}
%    y'' - 2y' - y = -1+t\\
%     y(0)=2\\
%     y'(0)=\frac{1}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
%
% ## F14
% \begin{gather*}
%    y'' - 2y' + y = t^2+t\\
%     y(0)=2\\
%     y'(0)=-\frac{2}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
%
% ## F15
% \begin{gather*}
%    y'' - 2.5y' - y = -1+t\\
%     y(0)=1\\
%     y'(0)=-\frac{2}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
%
% ## F16
% \begin{gather*}
%    y'' + 2y' - 3y = 1-t\\
%     y(0)=0\\
%     y'(0)=-\frac{2}{10}\\
% y(2)=?
% \end{gather*}
%
% ---
