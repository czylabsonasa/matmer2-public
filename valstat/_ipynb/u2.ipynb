% %% [markdown]
% Válasszunk a $[-1,1]$-ből véletlenszerűen egy számot, majd emeljük négyzetre!
% A kapott (véletlen) mennyiséget jelöljük $X$-el.
% 1. adjuk meg $X$ eloszlásfüggvényét!
% 2. adjuk meg $X$ sűrűségfüggvényét!
%
%
% 1.
%  $$
%  P(X<x)=
%  \begin{cases}
%  0  & x\leq 0\\
%  (*)& 0<x\leq 1\\
%  1  &  x>1
%  \end{cases}
%  $$
%  $$
%  (*)=P(Y^2<x)=P(|Y|<\sqrt{x})=
%  $$
%  $$
%  =P(-\sqrt{x}<Y<\sqrt{x})=F_{Y}(\sqrt{x})-F_{Y}(-\sqrt{x})=\sqrt{x}
%  $$
%  mivel $Y$ egy $[-1,1]$-en
%  egyenletes v.v., így eloszlásfv-e: $\frac{x+1}{2}$.
%
% 2. a sfv: $\frac{1}{2\sqrt{x}}$ $[0,1]$-en, máskor $0$.

% %% [markdown]
% 1. Végezzük el az előző feladatbeli kísérletet $100000$-szer.
% Ábrázoljuk histogramon az eredményt!
% 1. Ha $\Delta x$ kicsi akkor
% $$
% f\left(x+\frac{\Delta}{2}\right)\Delta x \simeq F(x+\Delta x)-F(x)=P(x\leq X<x+\Delta x)
% $$
% emiatt a histogramon látható dobozok magasságát (gyakoriság), közelítőleg megkaphatjuk a sfv.-ből. (relatív gyakoriság)

% %%
# 1
N=1e5;
X=(2*rand(N,1)-1).^2;
hist(X)
# 2
dx=0.1;
dom=0.05:0.1:1;
f=@(x) 0.5./sqrt(x);
hold on
plot(dom,N*dx*f(dom))
plot(dom,N*dx*f(dom),'o')

% %% [markdown]
% Miért rossz a közelítés a $0$ közelében?
